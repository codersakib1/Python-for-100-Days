# %%
#Kaun Banega Crorepati: Exercise-3 solution & shoutouts

# %%
questions = [
    [
        "Which language was used to create fb?", "Python", "JavaScript", "Php", "None", 4
     ],

    [
        "Which language was used to create fb?", "Python", "JavaScript", "Php", "None", 4
     ],

     [
         "Which language was used to create fb?", "Python", "JavaScript", "Php", "None", 4
     ],

     [
         "Which language was used to create fb?", "Python", "JavaScript", "Php", "None", 4
     ],
     [
         "Which language was used to create fb?", "Python", "JavaScript", "Php", "None", 4
     ],
     [
         "Which language was used to create fb?", "Python", "JavaScript", "Php", "None", 4
     ],
     [
         "Which language was used to create fb?", "Python", "JavaScript", "Php", "None", 4
     ],
     [
         "Which language was used to create fb?", "Python", "JavaScript", "Php", "None", 4
     ],

]

levels = [1000, 2000, 3000, 5000, 20000, 40000, 80000, 160000, 320000]
money = 0

for i in range (0, len(questions)):
    question = questions[i]
    print(f"\n\nQuestion for Rs. {levels[i]}")
    print(f"a. {question[1]}       b.{question[2]} ")
    print(f"c. {question[3]}       d.{question[4]} ")
    reply = int(input("Enter your answer (1-4)"))
    if(reply ==question[-1]):
        print(f"Correct answer, you have Rs. {levels[i]}")
        if(i == 4):
            money = 10000
        elif(i==9):
            money = 320000
        elif(i==14):
            money = 10000000
    else:
        print("Wrong answer!")
        break


print("Your take home money is {money}")
# Out:
# Question for Rs. 1000
# a. Python       b.JavaScript
# c. Php       d.None
# Correct answer, you have Rs. 1000
#
#
# Question for Rs. 2000
# a. Python       b.JavaScript
# c. Php       d.None
# Correct answer, you have Rs. 2000
#
#
# Question for Rs. 3000
# a. Python       b.JavaScript
# c. Php       d.None
# Correct answer, you have Rs. 3000
#
#
# Question for Rs. 5000
# a. Python       b.JavaScript
# c. Php       d.None
# Correct answer, you have Rs. 5000
#
#
# Question for Rs. 20000
# a. Python       b.JavaScript
# c. Php       d.None
# Correct answer, you have Rs. 20000
#
#
# Question for Rs. 40000
# a. Python       b.JavaScript
# c. Php       d.None
# Correct answer, you have Rs. 40000
#
#
# Question for Rs. 80000
# a. Python       b.JavaScript
# c. Php       d.None
# Correct answer, you have Rs. 80000
#
#
# Question for Rs. 160000
# a. Python       b.JavaScript
# c. Php       d.None
# Correct answer, you have Rs. 160000
# Your take home money is {money}
